# %% [markdown]
# # Mid-term test
#
# ## Важная информация
# - Дедлайн **11.10 23:59**
# - Название файла: 'группа_фамилия_имя.*' (пример 877_tsimboy_olga.ipynb)
# - Присылать на tsimboy.oa@phystech.edu, тема: CM_HW_MidTerm
# - Любые источники должны цитироваться
# - Код должен быть readable & reproducible(reproducible = restart & run all без ошибок)
# - Оставляйте комментарии, если задача куска кода не очевидна из контекста

# %% [markdown]
# # Численное дифференцирование
# $$f'(x) = \frac{\alpha f(x - h) + \beta f(x) + \gamma f(x + h)}{h}$$
#
# Найти коэффициенты так, чтобы опядок аппроксимации был максимальным.

# %% [markdown]
# # Свойства норм (достаточно решить 2 из 3)
#
# ### 1
# Пусть задана $\|\cdot\|$, дуальной нормой называется:
# $$\|x\|_{*} = \max_{y\neq 0}\frac{|x^{\top}y|}{\|y\|}$$
# Показать, что для $p$-нормы, дуальной будет $q$-норма. Как связаны $p$, $q$?
# ### 2
# Может ли норма подматрицы быть больше нормы матрицы ?
#
# ### 3
# Пусть матрица $A$ сохраняет $p$-норму, доказать, что $A^{\top}$ сохраняет $q$-норму

# %% [markdown]
# # Прямые методы решения СЛАУ, число обусловленности. (3 теоретические задачи и 3 практические)
#
# ### 1
# - Покажите, что матрица Фурье унитарная.
# - Пусть $A = I + \alpha uu^*,~\|u\|_1 = 1$. Найти все $\alpha$, при который матрицы будет унитарной.
#
# ### 2
# Означает ли $|\det A| = 1$ хорошую обусловленность матрицы ? Означает ли  плохую $|\det A| << 1$?
#
# ### 3
# Найти $\rm cond_{\infty}$ для
# $$
# \begin{bmatrix}
# 1 & 2 & 0 & \ldots & 0\\
# 0 & 1 & 2 & \ldots \\
# \vdots & \vdots & \ddots & \ddots & \vdots\\
# 0 & \ldots & 0 & 0 & 1 \\
# \end{bmatrix}_{n \times n}
# $$
#
# ### 4
# Написать программу решения системы с матрицей выше и вектором $b = (1,~1, \ldots, 1/3)$
#
# ### 5
# Придумать алгоритм для решения треугольной системы за $O(\log^2_2n)$ и реализовать его.
#
# ### 6
# Реализуйте ортогонализацию Грамма-Шмидта. Проверьте насколько матрицы ортогональны на примере матрицы Гильберта. Объясните результаты, сравните с ортогонализацией с помощью отражений Хаусхолдера.
#
# ### 7
# Реализовать метод, обобщающий степенной для нахождения $k$ собственных векторов и значений.
# Сравните с методом, основанном на корнях характеристического многочлена для матрицы Гильберта. Объесните результаты.
#
# ### 9
# Написать обращение верхнетреугольной матрицы за $O(n^2)$

# %% [markdown]
# # Итерационные метода решения СЛАУ
# Размерность матрицы $n > 100$
#
# ### 1
#
# - Реализовать метод Ричардсона для положительно определенной матрицы с оптимальным шагом: используя `scipy.linalg.eigvals` и оценив собственные значения, используя следующее утверждение
#
# __Утверждение:__ Собственные значение $\lambda_i,~i = 1, \ldots, n$ содердатся в объединении кругов $C_i$ с центром в $a_{ii}$ и радиусом $r_i = \sum_{i, i\neq j}|a_{ij}|$
#
#
# - Найти характеристический многочлен для методов: Якоби, Зейделя, SOR, для последнего найти корни. Упростить итерационную схему SOR при $\omega = 1$. Сгенерировать матрицу системы из $\mathbb{S}^n_{++}$, реализовать SOR, постролить графики сходимости для различных $\omega$ из $(0, 2)$ (сделайте равномерную сетку по $\omega$), найдите по графику оптимальный параметр.

# %% [markdown]
# # Нелинейные уравнения (2 задачи)
#
# ### 1
# Записать метод Ньютона для решения уравнения $A - X^{-1} = 0$. (Я знаю что это вы уже должны были делать на оптах). Реализуйте его. Исследуйте сходимость.
#
# ### 2
# Выясните сходимость метода простой итерации при различных начальных приближениях для
# $$x = e^{2x} - 1$$
# $$x + \ln x = 0.5$$
# $$x = \tan x$$
